# %% [markdown]
# # Optimisation: Compilation
#
# Compilation is the act of a program, known as a compiler, examining source code and creating a new piece of executable code which may be executed later. Compilation offers a few useful advantages. A compiler can check the syntax of all the code of a program before it is run, which can aid finding problems in the code. Of more immediate use to us, however, is the fact that compilers can interpret our code and write a more efficient piece of code in a lower level language which is guaranteed to produce the same result. This is the property of compilation that we can use to speed up code written in Python.
#
# Some languages are, by default, compiled languages, such as Fortran and C. Code written in these languages are usually compiled before they are run. In these cases, a separate exceutable file is normally created and this is what is run, without reference to the source code at all.
#
# Python code can be compiled this way, but there are other, more convenient ways of using the idea of compilation to speed up Python code.
#
# ## Numba
#
# [Numba](http://numba.pydata.org/) is an example of a Python tool which harnesses the power of compilation to speed up existing Python code with minimal changes to code required. Many of the features in Numba are accessed by adding various decorators to functions. Let's look at a simple example now.
#
# The following example is taken from a series of short examples from the [Numba website](https://numba.pydata.org/). The first code calcualtes the value of $\pi$ using the same method we used in the Parallelism notebook. In the second code cell we import the ```jit``` decorator from the ```numba``` package and add the decorator ```@jit(nopython=True)``` to the function. This causes Numba to compile the function just before it's run and for Python to run the compiled function. Here, ```jit``` stands for "just in time" as the compilation is happening just before the function is run. The ```nonpython = true``` forces Numba to attempt to compile the function using faster, non-Python, code.
#
# If you're running this Jupyter Notebook on your computer, as opposed to Colab, you may need to install the Numba package before you can run the code.

# %%
import random
import cProfile

def monte_carlo_pi(nsamples):
    acc = 0
    for i in range(nsamples):
        x = random.random()
        y = random.random()
        if (x ** 2 + y ** 2) < 1.0:
            acc += 1
    return 4.0 * acc / nsamples

cProfile.run('print(monte_carlo_pi(10000000))')
# Out:
# 3.1410004
#          20000029 function calls in 7.078 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    5.707    5.707    7.078    7.078 144883930.py:4(monte_carlo_pi)
#         1    0.000    0.000    7.078    7.078 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 iostream.py:202(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:437(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:456(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:526(write)
#         1    0.000    0.000    0.000    0.000 iostream.py:90(_event_pipe)
#         1    0.000    0.000    0.000    0.000 socket.py:543(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1059(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1113(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:529(is_set)
#         1    0.000    0.000    7.078    7.078 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         2    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#  20000000    1.371    0.000    1.371    0.000 {method 'random' of '_random.Random' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
# Import the jit decorator from the numba package
from numba import jit
import random
import cProfile

# Apply the jit decorator to our function
@jit(nopython=True) #~LARGE OVERHEADS IN THE COMPILATION
def monte_carlo_pi(nsamples):
    acc = 0
    for i in range(nsamples):
        x = random.random()
        y = random.random()
        if (x ** 2 + y ** 2) < 1.0:
            acc += 1
    return 4.0 * acc / nsamples

cProfile.run('monte_carlo_pi(10000000)')
# Out:
#          702843 function calls (672994 primitive calls) in 0.776 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.117    0.117    0.117    0.117 1545241486.py:7(monte_carlo_pi)
#       986    0.001    0.000    0.001    0.000 <__array_function__ internals>:2(can_cast)
#    180/93    0.001    0.000    0.276    0.003 <frozen importlib._bootstrap>:1002(_find_and_load)
#     60/58    0.000    0.000    0.023    0.000 <frozen importlib._bootstrap>:1018(_gcd_import)
# 3475/3264    0.004    0.000    0.274    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#       266    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:112(release)
#       180    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:152(__init__)
#       180    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap>:156(__enter__)
#       180    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:160(__exit__)
#       266    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap>:166(_get_module_lock)
#       234    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:185(cb)
#        86    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:203(_lock_unlock_module)
#    192/38    0.000    0.000    0.262    0.007 <frozen importlib._bootstrap>:220(_call_with_frames_removed)
#       729    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:231(_verbose_message)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:241(_requires_builtin_wrapper)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:278(_module_repr)
#       100    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:35(_new_module)
#       124    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:351(__init__)
#       218    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap>:385(cached)
#       489    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:398(parent)
#       125    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:406(has_location)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:415(spec_from_loader)
#       119    0.001    0.000    0.004    0.000 <frozen importlib._bootstrap>:486(_init_module_attrs)
#       119    0.000    0.000    0.075    0.001 <frozen importlib._bootstrap>:558(module_from_spec)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:575(_module_repr_from_spec)
#       234    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:58(__init__)
#    119/38    0.001    0.000    0.261    0.007 <frozen importlib._bootstrap>:659(_load_unlocked)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:727(module_repr)
#       124    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:736(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:757(create_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:765(exec_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:782(is_package)
#       123    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:811(find_spec)
#       266    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:87(acquire)
#       380    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:874(__enter__)
#       380    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:878(__exit__)
#        57    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:883(_resolve_name)
#       124    0.001    0.000    0.029    0.000 <frozen importlib._bootstrap>:901(_find_spec)
#        60    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:948(_sanity_check)
#    125/38    0.001    0.000    0.274    0.007 <frozen importlib._bootstrap>:967(_find_and_load_unlocked)
#       100    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1006(__init__)
#       100    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1031(get_filename)
#       100    0.001    0.000    0.072    0.001 <frozen importlib._bootstrap_external>:1036(get_data)
#       100    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:1077(path_stats)
#       586    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:114(<listcomp>)
#        18    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1155(__init__)
#        18    0.000    0.000    0.070    0.004 <frozen importlib._bootstrap_external>:1171(create_module)
#     18/15    0.000    0.000    0.010    0.001 <frozen importlib._bootstrap_external>:1179(exec_module)
#       200    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:127(_path_split)
#       600    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:129(<genexpr>)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1324(_path_hooks)
#       132    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1337(_path_importer_cache)
#       363    0.000    0.000    0.023    0.000 <frozen importlib._bootstrap_external>:135(_path_stat)
#       123    0.001    0.000    0.028    0.000 <frozen importlib._bootstrap_external>:1374(_get_spec)
#       123    0.000    0.000    0.028    0.000 <frozen importlib._bootstrap_external>:1406(find_spec)
#       128    0.000    0.000    0.013    0.000 <frozen importlib._bootstrap_external>:145(_path_is_mode_type)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1466(__init__)
#        32    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1472(<genexpr>)
#       118    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1500(_get_spec)
#       131    0.001    0.000    0.026    0.000 <frozen importlib._bootstrap_external>:1505(find_spec)
#       124    0.000    0.000    0.013    0.000 <frozen importlib._bootstrap_external>:154(_path_isfile)
#         4    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1556(_fill_cache)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1585(<setcomp>)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:159(_path_isdir)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1597(path_hook_for_FileFinder)
#        22    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:167(_path_isabs)
#       200    0.001    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:361(cache_from_source)
#       118    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:491(_get_cached)
#       100    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:523(_check_name_wrapper)
#       100    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:560(_classify_pyc)
#       100    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:593(_validate_timestamp_pyc)
#       131    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:64(_relax_case)
#       100    0.000    0.000    0.012    0.000 <frozen importlib._bootstrap_external>:645(_compile_bytecode)
#       118    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:696(spec_from_file_location)
#       300    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:79(_unpack_uint32)
#       100    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:841(create_module)
#    100/38    0.000    0.000    0.259    0.007 <frozen importlib._bootstrap_external>:844(exec_module)
#       586    0.004    0.000    0.006    0.000 <frozen importlib._bootstrap_external>:91(_path_join)
#       100    0.001    0.000    0.093    0.001 <frozen importlib._bootstrap_external>:916(get_code)
#         4    0.000    0.000    0.000    0.000 <frozen zipimport>:63(__init__)
#         3    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <string>:2(<module>)
#         3    0.000    0.000    0.165    0.055 __init__.py:1(<module>)
#     57/55    0.000    0.000    0.023    0.000 __init__.py:10(__getattr__)
#     60/58    0.000    0.000    0.023    0.000 __init__.py:109(import_module)
#         3    0.000    0.000    0.000    0.000 __init__.py:1276(disable)
#        95    0.000    0.000    0.002    0.000 __init__.py:1393(_get_metadata_path)
#        81    0.000    0.000    0.005    0.000 __init__.py:1396(has_metadata)
#        14    0.000    0.000    0.007    0.001 __init__.py:1403(get_metadata)
#        14    0.000    0.000    0.007    0.001 __init__.py:1416(get_metadata_lines)
#      1642    0.000    0.000    0.001    0.000 __init__.py:1424(debug)
#        95    0.000    0.000    0.002    0.000 __init__.py:1472(_fn)
#        95    0.000    0.000    0.001    0.000 __init__.py:1478(_validate_resource_path)
#        81    0.000    0.000    0.003    0.000 __init__.py:1598(_has)
#        14    0.000    0.000    0.007    0.000 __init__.py:1610(_get)
#         3    0.000    0.000    0.000    0.000 __init__.py:1675(getEffectiveLevel)
#      1642    0.000    0.000    0.000    0.000 __init__.py:1689(isEnabledFor)
#         2    0.000    0.000    0.000    0.000 __init__.py:1886(has_metadata)
#         1    0.000    0.000    0.000    0.000 __init__.py:216(<listcomp>)
#         3    0.000    0.000    0.000    0.000 __init__.py:218(_acquireLock)
#         3    0.000    0.000    0.000    0.000 __init__.py:227(_releaseLock)
#   729/275    0.000    0.000    0.013    0.000 __init__.py:2385(yield_lines)
#         5    0.000    0.000    0.000    0.000 __init__.py:24(_module_matches_namespace)
#        76    0.000    0.000    0.000    0.000 __init__.py:2417(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:242(<listcomp>)
#        76    0.000    0.000    0.000    0.000 __init__.py:2484(parse)
#        76    0.000    0.000    0.000    0.000 __init__.py:2504(_parse_extras)
#        20    0.000    0.000    0.001    0.000 __init__.py:2513(parse_group)
#        83    0.000    0.000    0.014    0.000 __init__.py:2526(parse_map)
#       179    0.000    0.000    0.013    0.000 __init__.py:2763(_get_metadata)
#       180    0.000    0.000    0.000    0.000 __init__.py:2810(__getattr__)
#        83    0.000    0.000    0.014    0.000 __init__.py:2848(get_entry_map)
#       172    0.000    0.000    0.013    0.000 __init__.py:3180(split_sections)
#        13    0.001    0.000    0.002    0.000 __init__.py:345(namedtuple)
#         1    0.000    0.000    0.000    0.000 __init__.py:392(__getattr__)
#         1    0.000    0.000    0.000    0.000 __init__.py:399(__getitem__)
#        89    0.000    0.000    0.000    0.000 __init__.py:419(<genexpr>)
#         6    0.000    0.000    0.000    0.000 __init__.py:48(create_string_buffer)
#        22    0.000    0.000    0.000    0.000 __init__.py:517(cast)
#         3    0.000    0.000    0.000    0.000 __init__.py:521(string_at)
#         5    0.000    0.000    0.000    0.000 __init__.py:57(find_spec)
#        88    0.000    0.000    0.000    0.000 __init__.py:581(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:595(__missing__)
#         1    0.000    0.000    0.000    0.000 __init__.py:631(iter_entry_points)
#         1    0.000    0.000    0.015    0.015 __init__.py:638(<genexpr>)
#        88    0.000    0.000    0.000    0.000 __init__.py:649(update)
#        84    0.000    0.000    0.000    0.000 __init__.py:653(__iter__)
#         1    0.000    0.000    0.000    0.000 __init__.py:989(__setitem__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:262(__subclasshook__)
#        15    0.000    0.000    0.000    0.000 _collections_abc.py:315(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:409(__subclasshook__)
#       404    0.000    0.000    0.002    0.000 _collections_abc.py:767(__contains__)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:775(keys)
#         6    0.000    0.000    0.000    0.000 _collections_abc.py:779(items)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:78(_check_methods)
#         9    0.000    0.000    0.000    0.000 _collections_abc.py:802(__init__)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:805(__len__)
#        24    0.000    0.000    0.000    0.000 _collections_abc.py:825(__iter__)
#       252    0.000    0.000    0.001    0.000 _collections_abc.py:849(__iter__)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:925(clear)
#         5    0.000    0.000    0.000    0.000 _collections_abc.py:980(__iter__)
#         1    0.000    0.000    0.000    0.000 _decomp_cossin.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 _decomp_ldl.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _decomp_polar.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _decomp_qz.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _expm_frechet.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _index.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _index.py:28(IndexMixin)
#         1    0.000    0.000    0.000    0.000 _laplacian.py:1(<module>)
#         1    0.000    0.000    0.002    0.002 _matfuncs_sqrtm.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _matfuncs_sqrtm.py:20(SqrtmError)
#         1    0.000    0.000    0.000    0.000 _matrix_io.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _procrustes.py:1(<module>)
#         1    0.000    0.000    0.033    0.033 _sketches.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _solvers.py:1(<module>)
#         3    0.000    0.000    0.000    0.000 _testutils.py:24(__init__)
#         1    0.000    0.000    0.000    0.000 _util.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _util.py:174(DeprecatedImport)
#         2    0.000    0.000    0.000    0.000 _util.py:192(__init__)
#         1    0.000    0.000    0.000    0.000 _util.py:404(MapWrapper)
#      1901    0.000    0.000    0.000    0.000 _utils.py:13(is_used)
#      1061    0.001    0.000    0.003    0.000 _utils.py:16(register)
#       997    0.001    0.000    0.002    0.000 _utils.py:24(deduplicate)
# 2509/1087    0.001    0.000    0.009    0.000 _utils.py:44(__str__)
# 1897/1885    0.001    0.000    0.003    0.000 _utils.py:54(get_reference)
#        27    0.000    0.000    0.000    0.000 _utils.py:64(set_metadata)
#       698    0.000    0.000    0.000    0.000 _utils.py:71(_stringify_metadata)
#        27    0.000    0.000    0.000    0.000 _utils.py:76(<listcomp>)
#        69    0.000    0.000    0.000    0.000 _utils.py:9(__init__)
#         1    0.000    0.000    0.001    0.001 _validation.py:1(<module>)
#      1138    0.001    0.000    0.016    0.000 abc.py:105(__new__)
#      7491    0.002    0.000    0.006    0.000 abc.py:117(__instancecheck__)
# 5217/3146    0.001    0.000    0.006    0.000 abc.py:121(__subclasscheck__)
#       522    0.000    0.000    0.000    0.000 abstract.py:114(__repr__)
# 3501/3239    0.002    0.000    0.003    0.000 abstract.py:117(__hash__)
# 4728/4549    0.002    0.000    0.002    0.000 abstract.py:120(__eq__)
#       126    0.000    0.000    0.000    0.000 abstract.py:123(__ne__)
#         6    0.000    0.000    0.000    0.000 abstract.py:130(unify)
#         4    0.000    0.000    0.000    0.000 abstract.py:139(can_convert_to)
#         8    0.000    0.000    0.000    0.000 abstract.py:147(can_convert_from)
#       324    0.000    0.000    0.000    0.000 abstract.py:154(is_precise)
#        10    0.000    0.000    0.000    0.000 abstract.py:173(__call__)
#      1373    0.000    0.000    0.001    0.000 abstract.py:19(_autoincr)
#         3    0.000    0.000    0.000    0.000 abstract.py:249(unify)
#       205    0.000    0.000    0.000    0.000 abstract.py:27(_on_type_disposal)
#        14    0.000    0.000    0.000    0.000 abstract.py:429(_literal_init)
#        27    0.000    0.000    0.000    0.000 abstract.py:435(literal_value)
#       152    0.000    0.000    0.000    0.000 abstract.py:439(literal_type)
#         3    0.000    0.000    0.000    0.000 abstract.py:464(__init__)
#        15    0.000    0.000    0.000    0.000 abstract.py:468(key)
#      1588    0.002    0.000    0.006    0.000 abstract.py:48(_intern)
# 1588/1586    0.002    0.000    0.015    0.000 abstract.py:60(__call__)
#      1588    0.000    0.000    0.000    0.000 abstract.py:92(__init__)
#      4704    0.001    0.000    0.001    0.000 abstract.py:95(key)
#        27    0.002    0.000    0.004    0.000 analysis.py:118(compute_dead_maps)
#       444    0.000    0.000    0.000    0.000 analysis.py:138(<genexpr>)
#       354    0.000    0.000    0.000    0.000 analysis.py:141(<genexpr>)
#       237    0.000    0.000    0.000    0.000 analysis.py:182(<genexpr>)
#        27    0.001    0.000    0.001    0.000 analysis.py:190(compute_live_variables)
#        83    0.000    0.000    0.000    0.000 analysis.py:200(fix_point_progress)
#        30    0.003    0.000    0.019    0.001 analysis.py:23(compute_use_defs)
#        72    0.001    0.000    0.004    0.000 analysis.py:235(compute_cfg_from_blocks)
#         6    0.000    0.000    0.001    0.000 analysis.py:291(dead_branch_prune)
#         6    0.000    0.000    0.000    0.000 analysis.py:304(find_branches)
#         2    0.000    0.000    0.000    0.000 analysis.py:322(do_prune)
#         2    0.000    0.000    0.000    0.000 analysis.py:360(prune_by_predicate)
#         6    0.000    0.000    0.000    0.000 analysis.py:375(Unknown)
#         2    0.000    0.000    0.000    0.000 analysis.py:378(resolve_input_arg_const)
#      1308    0.000    0.000    0.000    0.000 analysis.py:40(<genexpr>)
#         6    0.000    0.000    0.000    0.000 analysis.py:487(<listcomp>)
#         3    0.000    0.000    0.000    0.000 analysis.py:580(rewrite_semantic_constants)
#        27    0.000    0.000    0.004    0.000 analysis.py:60(compute_live_map)
#        55    0.000    0.000    0.000    0.000 analysis.py:607(rewrite_array_ndim)
#        55    0.000    0.000    0.000    0.000 analysis.py:617(rewrite_tuple_len)
#         3    0.000    0.000    0.000    0.000 analysis.py:646(find_literally_calls)
#       202    0.000    0.000    0.001    0.000 analysis.py:66(fix_point_progress)
#      1890    0.000    0.000    0.000    0.000 analysis.py:69(<genexpr>)
#        54    0.000    0.000    0.004    0.000 analysis.py:71(fix_point)
#        72    0.001    0.000    0.002    0.000 analysis.py:81(def_reach)
#        76    0.001    0.000    0.001    0.000 analysis.py:91(liveness)
#       404    0.000    0.000    0.000    0.000 ansitowin32.py:114(should_wrap)
#       404    0.000    0.000    0.000    0.000 ansitowin32.py:124(get_win32_calls)
#       404    0.000    0.000    0.000    0.000 ansitowin32.py:22(__init__)
#       404    0.000    0.000    0.002    0.000 ansitowin32.py:49(isatty)
#       404    0.000    0.000    0.000    0.000 ansitowin32.py:61(closed)
#       404    0.001    0.000    0.009    0.000 ansitowin32.py:81(__init__)
#         3    0.000    0.000    0.000    0.000 array_exprs.py:26(__init__)
#        21    0.000    0.000    0.000    0.000 array_exprs.py:33(match)
#         1    0.000    0.000    0.001    0.001 arraydecl.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:164(GetItemBuffer)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:174(SetItemBuffer)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:244(ArrayAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:519(DTypeAttr)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:537(StaticGetItemArray)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:560(RecordAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:570(StaticGetItemRecord)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:586(StaticGetItemLiteralRecord)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:610(StaticSetItemRecord)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:634(StaticSetItemLiteralRecord)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:649(ArrayCTypesAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:657(ArrayFlagsAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:671(NestedArrayAttribute)
#         9    0.000    0.000    0.000    0.000 arraydecl.py:810(install_array_method)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:842(CmpOpEqArray)
#         1    0.000    0.000    0.127    0.127 arraymath.py:1(<module>)
#         4    0.000    0.000    0.000    0.000 arraymath.py:1026(nan_min_max_factory)
#         2    0.000    0.000    0.000    0.000 arraymath.py:1251(_compute_current_val_impl_gen)
#         2    0.000    0.000    0.000    0.000 arraymath.py:1344(_partition_factory)
#         2    0.000    0.000    0.000    0.000 arraymath.py:1385(_select_factory)
#         2    0.000    0.000    0.000    0.000 arraymath.py:2320(np_interp_impl_complex_fp_inner_factory)
#         2    0.000    0.000    0.000    0.000 arraymath.py:2534(np_interp_impl_inner_factory)
#         1    0.000    0.000    0.119    0.119 arraymath.py:36(_check_blas)
#         2    0.000    0.000    0.000    0.000 arraymath.py:3742(_searchsorted)
#         2    0.000    0.000    0.000    0.000 arraymath.py:4055(generate_xinfo)
#         1    0.000    0.000    0.000    0.000 arraymath.py:4116(_corr_conv_Mode)
#         4    0.000    0.000    0.000    0.000 arraymath.py:4485(window_generator)
#         1    0.000    0.000    0.009    0.009 arrayobj.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:558(Indexer)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:608(EntireIndexer)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:658(IntegerIndexer)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:689(IntegerArrayIndexer)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:750(BooleanArrayIndexer)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:831(SliceIndexer)
#         1    0.000    0.000    0.000    0.000 arrayobj.py:900(FancyIndexer)
#         2    0.000    0.000    0.004    0.002 base.py:1(<module>)
#        55    0.000    0.000    0.000    0.000 base.py:104(<lambda>)
#       970    0.001    0.000    0.006    0.000 base.py:107(_match_arglist)
#        14    0.000    0.000    0.004    0.000 base.py:1111(get_abi_sizeof)
#        42    0.000    0.000    0.000    0.000 base.py:1145(active_code_library)
#         6    0.000    0.000    0.000    0.000 base.py:1151(push_code_library)
#        39    0.000    0.000    0.000    0.000 base.py:1161(add_linking_libs)
#        39    0.000    0.000    0.002    0.000 base.py:1194(__init__)
#         1    0.000    0.000    0.000    0.000 base.py:12(SparseWarning)
#     39/14    0.000    0.000    0.149    0.011 base.py:1200(__call__)
#        39    0.000    0.000    0.000    0.000 base.py:1205(__getattr__)
#        39    0.000    0.000    0.002    0.000 base.py:1211(_has_loc)
#        39    0.000    0.000    0.000    0.000 base.py:1220(__init__)
#        39    0.000    0.000    0.002    0.000 base.py:1223(__call__)
#     39/14    0.000    0.000    0.149    0.011 base.py:1229(wrapper)
#      1089    0.001    0.000    0.006    0.000 base.py:1257(enter_fn)
#      1089    0.001    0.000    0.007    0.000 base.py:1260(exit_fn)
#      1075    0.001    0.000    0.004    0.000 base.py:127(_match)
#      1161    0.001    0.000    0.001    0.000 base.py:142(append)
#         1    0.000    0.000    0.000    0.000 base.py:16(SparseFormatWarning)
#         1    0.000    0.000    0.000    0.000 base.py:20(SparseEfficiencyWarning)
#         1    0.000    0.000    0.000    0.000 base.py:22(InstanceModel)
#         1    0.000    0.000    0.000    0.000 base.py:258(ConstructorTemplate)
#     175/5    0.000    0.000    0.286    0.057 base.py:269(refresh)
#         6    0.000    0.000    0.000    0.000 base.py:292(mangler)
#         6    0.000    0.000    0.000    0.000 base.py:298(get_env_name)
#         1    0.000    0.000    0.000    0.000 base.py:300(ClassBuilder)
#         4    0.000    0.000    0.000    0.000 base.py:306(declare_env_global)
#        27    0.000    0.000    0.000    0.000 base.py:327(get_arg_packer)
#         1    0.000    0.000    0.000    0.000 base.py:337(nonconst_module_attrs)
#         2    0.000    0.000    0.002    0.001 base.py:344(nrt)
#         6    0.000    0.000    0.000    0.000 base.py:349(subtarget)
#      1400    0.003    0.000    0.018    0.000 base.py:360(install_registry)
#         1    0.000    0.000    0.000    0.000 base.py:37(InstanceDataModel)
#      1400    0.001    0.000    0.005    0.000 base.py:376(insert_func_defn)
#      1400    0.000    0.000    0.002    0.000 base.py:380(_insert_getattr_defn)
#      1400    0.000    0.000    0.002    0.000 base.py:384(_insert_setattr_defn)
#      1400    0.000    0.000    0.002    0.000 base.py:388(_insert_cast_defn)
#      1400    0.000    0.000    0.002    0.000 base.py:392(_insert_get_constant_defn)
#         2    0.000    0.000    0.000    0.000 base.py:396(insert_user_function)
#         1    0.000    0.000    0.000    0.000 base.py:398(ClassAttribute)
#       497    0.000    0.000    0.000    0.000 base.py:41(__init__)
#         7    0.000    0.000    0.001    0.000 base.py:429(declare_function)
#         7    0.000    0.000    0.000    0.000 base.py:445(insert_const_string)
#       112    0.000    0.000    0.008    0.000 base.py:46(find)
#        19    0.000    0.000    0.000    0.000 base.py:465(insert_unique_const)
#         9    0.000    0.000    0.000    0.000 base.py:477(get_argument_type)
#        73    0.000    0.000    0.000    0.000 base.py:493(get_value_type)
#        54    0.000    0.000    0.004    0.000 base.py:514(get_constant_generic)
#         6    0.000    0.000    0.000    0.000 base.py:524(get_constant)
#        49    0.000    0.000    0.007    0.000 base.py:53(_find)
#        39    0.000    0.000    0.004    0.000 base.py:540(get_function)
#         1    0.000    0.000    0.000    0.000 base.py:58(spmatrix)
#         3    0.000    0.000    0.000    0.000 base.py:590(get_getattr)
#        49    0.000    0.000    0.007    0.000 base.py:60(_select_compatible)
#         7    0.000    0.000    0.000    0.000 base.py:666(get_returned_value)
#         5    0.000    0.000    0.000    0.000 base.py:672(get_return_value)
#         1    0.000    0.000    0.000    0.000 base.py:689(pair_first)
#         1    0.000    0.000    0.000    0.000 base.py:696(pair_second)
#        49    0.000    0.000    0.000    0.000 base.py:70(_best_signature)
#   145/134    0.000    0.000    0.006    0.000 base.py:703(cast)
#         3    0.000    0.000    0.002    0.001 base.py:748(is_true)
#         8    0.000    0.000    0.000    0.000 base.py:757(get_c_value)
#        12    0.000    0.000    0.000    0.000 base.py:78(<lambda>)
#         1    0.000    0.000    0.000    0.000 base.py:807(get_struct_type)
#         1    0.000    0.000    0.000    0.000 base.py:81(JitClassType)
#         1    0.000    0.000    0.000    0.000 base.py:811(<listcomp>)
#        20    0.000    0.000    0.000    0.000 base.py:814(get_dummy_value)
#        20    0.000    0.000    0.000    0.000 base.py:817(get_dummy_type)
#         1    0.000    0.000    0.141    0.141 base.py:820(_compile_subroutine_no_cache)
#         2    0.000    0.000    0.141    0.071 base.py:858(compile_subroutine)
#        49    0.000    0.000    0.000    0.000 base.py:87(_sort_signatures)
#         8    0.000    0.000    0.000    0.000 base.py:874(<genexpr>)
#         2    0.000    0.000    0.143    0.072 base.py:887(compile_internal)
#         2    0.000    0.000    0.002    0.001 base.py:895(call_internal)
#         2    0.000    0.000    0.001    0.001 base.py:907(call_internal_no_propagate)
#         7    0.000    0.000    0.000    0.000 base.py:965(get_python_api)
#         3    0.000    0.000    0.000    0.000 base.py:986(get_helper_class)
#         3    0.000    0.000    0.000    0.000 base.py:994(_make_helper)
#         3    0.000    0.000    0.000    0.000 base.py:998(make_helper)
#         3    0.000    0.000    0.000    0.000 base64.py:51(b64encode)
#         1    0.000    0.000    0.006    0.006 basic.py:7(<module>)
#         1    0.000    0.000    0.044    0.044 blas.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 blas.py:238(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 blas.py:239(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 blas.py:376(_memoize_get_funcs)
#         1    0.000    0.000    0.000    0.000 boxing.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 boxing.py:46(unbox_integer)
#         1    0.000    0.000    0.000    0.000 boxing.py:599(_NumbaTypeHelper)
#         1    0.000    0.000    0.000    0.000 boxing.py:62(box_float)
#         1    0.000    0.000    0.000    0.000 bsr.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 bsr.py:22(bsr_matrix)
#         1    0.000    0.000    0.000    0.000 bufproto.py:1(<module>)
#        10    0.000    0.000    0.000    0.000 builder.py:160(wrapped)
#        71    0.000    0.000    0.000    0.000 builder.py:173(_label_suffix)
#         6    0.000    0.000    0.000    0.000 builder.py:190(__init__)
#      1203    0.000    0.000    0.000    0.000 builder.py:195(block)
#       155    0.000    0.000    0.000    0.000 builder.py:204(function)
#        18    0.000    0.000    0.000    0.000 builder.py:211(module)
#         5    0.000    0.000    0.000    0.000 builder.py:218(position_before)
#       185    0.000    0.000    0.000    0.000 builder.py:241(position_at_end)
#        73    0.000    0.000    0.000    0.000 builder.py:248(append_basic_block)
#        92    0.000    0.000    0.000    0.000 builder.py:264(goto_block)
#        88    0.000    0.000    0.000    0.000 builder.py:281(goto_entry_block)
#        72    0.000    0.000    0.000    0.000 builder.py:290(_branch_helper)
#        68    0.000    0.000    0.002    0.000 builder.py:297(if_then)
#        64    0.000    0.000    0.001    0.000 builder.py:31(wrapped)
#         2    0.000    0.000    0.000    0.000 builder.py:320(if_else)
#       697    0.000    0.000    0.001    0.000 builder.py:351(_insert)
#       103    0.000    0.000    0.000    0.000 builder.py:357(_set_terminator)
#        11    0.000    0.000    0.000    0.000 builder.py:539(not_)
#         2    0.000    0.000    0.000    0.000 builder.py:550(neg)
#        62    0.000    0.000    0.001    0.000 builder.py:568(_icmp)
#        42    0.000    0.000    0.001    0.000 builder.py:579(icmp_signed)
#        20    0.000    0.000    0.000    0.000 builder.py:588(icmp_unsigned)
#         3    0.000    0.000    0.000    0.000 builder.py:597(fcmp_ordered)
#         9    0.000    0.000    0.000    0.000 builder.py:629(select)
#        45    0.000    0.000    0.001    0.000 builder.py:737(alloca)
#       149    0.000    0.000    0.002    0.000 builder.py:755(load)
#       151    0.000    0.000    0.002    0.000 builder.py:768(store)
#        39    0.000    0.000    0.000    0.000 builder.py:825(branch)
#        43    0.000    0.000    0.001    0.000 builder.py:833(cbranch)
#        21    0.000    0.000    0.000    0.000 builder.py:857(ret)
#        44    0.000    0.000    0.001    0.000 builder.py:874(call)
#        26    0.000    0.000    0.000    0.000 builder.py:921(gep)
#        32    0.000    0.000    0.000    0.000 builder.py:966(extract_value)
#         3    0.000    0.000    0.000    0.000 builtins.py:106(generic)
#         2    0.000    0.000    0.000    0.000 builtins.py:129(none_equality)
#         1    0.000    0.000    0.000    0.000 builtins.py:292(int_impl)
#         2    0.000    0.000    0.000    0.000 builtins.py:329(number_constructor)
#        17    0.000    0.000    0.000    0.000 builtins.py:351(constant_dummy)
#         6    0.000    0.000    0.000    0.000 builtins.py:437(generic)
#         4    0.000    0.000    0.000    0.000 builtins.py:443(bool_sequence)
#         4    0.000    0.000    0.000    0.000 builtins.py:459(bool_none)
#         4    0.000    0.000    0.000    0.000 builtins.py:797(resolve___call__)
#         4    0.000    0.000    0.000    0.000 builtins.py:803(typer)
#        20    0.000    0.000    0.000    0.000 builtins.py:939(generic)
#         3    0.000    0.000    0.000    0.000 builtins.py:95(generic)
#         2    0.000    0.000    0.000    0.000 builtins.py:968(generic)
#       136    0.000    0.000    0.000    0.000 bytecode.py:106(__repr__)
#       136    0.000    0.000    0.000    0.000 bytecode.py:130(_unpack_opargs)
#       139    0.000    0.000    0.000    0.000 bytecode.py:158(_patched_opargs)
#         3    0.000    0.000    0.000    0.000 bytecode.py:174(__init__)
#         3    0.000    0.000    0.000    0.000 bytecode.py:178(__iter__)
#         3    0.000    0.000    0.000    0.000 bytecode.py:18(get_function_object)
#       139    0.000    0.000    0.000    0.000 bytecode.py:181(_fetch_opcode)
#       139    0.000    0.000    0.000    0.000 bytecode.py:184(next)
#         3    0.000    0.000    0.001    0.000 bytecode.py:206(__init__)
#        14    0.000    0.000    0.000    0.000 bytecode.py:209(<genexpr>)
#         3    0.000    0.000    0.000    0.000 bytecode.py:225(_compute_lineno)
#       578    0.000    0.000    0.000    0.000 bytecode.py:247(__getitem__)
#         3    0.000    0.000    0.000    0.000 bytecode.py:253(dump)
#       136    0.000    0.000    0.000    0.000 bytecode.py:254(label_marker)
#       139    0.000    0.000    0.000    0.000 bytecode.py:260(<genexpr>)
#        47    0.000    0.000    0.000    0.000 bytecode.py:30(get_code_object)
#         3    0.000    0.000    0.000    0.000 bytecode.py:311(from_function)
#       136    0.000    0.000    0.000    0.000 bytecode.py:67(__init__)
#        30    0.000    0.000    0.000    0.000 bytecode.py:75(is_jump)
#        30    0.000    0.000    0.000    0.000 bytecode.py:83(get_jump_target)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1007(op_GET_ITER)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1013(op_FOR_ITER)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1036(_unaryop)
#        19    0.000    0.000    0.000    0.000 byteflow.py:1047(_binaryop)
#         3    0.000    0.000    0.000    0.000 byteflow.py:1168(op_LOAD_METHOD)
#         3    0.000    0.000    0.000    0.000 byteflow.py:1171(op_CALL_METHOD)
#        34    0.000    0.000    0.000    0.000 byteflow.py:1179(__init__)
#       223    0.000    0.000    0.000    0.000 byteflow.py:1216(get_identity)
#       209    0.000    0.000    0.000    0.000 byteflow.py:1219(__hash__)
#         7    0.000    0.000    0.000    0.000 byteflow.py:1225(__eq__)
#       139    0.000    0.000    0.000    0.000 byteflow.py:1228(pc_initial)
#        27    0.000    0.000    0.000    0.000 byteflow.py:1235(instructions)
#        54    0.000    0.000    0.000    0.000 byteflow.py:1242(outgoing_edges)
#        27    0.000    0.000    0.000    0.000 byteflow.py:1252(outgoing_phis)
#        27    0.000    0.000    0.000    0.000 byteflow.py:1261(blockstack_initial)
#        27    0.000    0.000    0.000    0.000 byteflow.py:1277(find_initial_try_block)
#       135    0.000    0.000    0.000    0.000 byteflow.py:1284(has_terminated)
#       416    0.000    0.000    0.000    0.000 byteflow.py:1287(get_inst)
#       111    0.000    0.000    0.000    0.000 byteflow.py:1290(advance_pc)
#       110    0.000    0.000    0.000    0.000 byteflow.py:1294(make_temp)
#       135    0.000    0.000    0.000    0.000 byteflow.py:1312(append)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1317(get_tos)
#         1    0.000    0.000    0.000    0.000 byteflow.py:1320(peek)
#       101    0.000    0.000    0.000    0.000 byteflow.py:1325(push)
#        94    0.000    0.000    0.000    0.000 byteflow.py:1329(pop)
#       115    0.000    0.000    0.000    0.000 byteflow.py:1376(get_top_block)
#       111    0.000    0.000    0.000    0.000 byteflow.py:1384(has_active_try)
#        27    0.000    0.000    0.000    0.000 byteflow.py:1389(get_varname)
#        40    0.000    0.000    0.000    0.000 byteflow.py:1394(terminate)
#        31    0.001    0.000    0.001    0.000 byteflow.py:1399(fork)
#         3    0.000    0.000    0.000    0.000 byteflow.py:1422(split_new_block)
#        27    0.000    0.000    0.000    0.000 byteflow.py:1427(get_outgoing_states)
#        27    0.000    0.000    0.000    0.000 byteflow.py:1442(get_outgoing_edgepushed)
#        27    0.000    0.000    0.000    0.000 byteflow.py:1451(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 byteflow.py:1461(__init__)
#        27    0.000    0.000    0.000    0.000 byteflow.py:1464(infos)
#        27    0.000    0.000    0.000    0.000 byteflow.py:1476(adapt_state_infos)
#        27    0.000    0.000    0.000    0.000 byteflow.py:148(<lambda>)
#   350/334    0.000    0.000    0.000    0.000 byteflow.py:1486(_flatten_inst_regs)
#         3    0.000    0.000    0.001    0.000 byteflow.py:1500(__init__)
#         3    0.000    0.000    0.000    0.000 byteflow.py:152(_build_cfg)
#       145    0.000    0.000    0.000    0.000 byteflow.py:1523(backbone)
#        33    0.000    0.000    0.000    0.000 byteflow.py:1527(blocks)
#        30    0.000    0.000    0.000    0.000 byteflow.py:1531(iterliveblocks)
#        27    0.000    0.000    0.000    0.000 byteflow.py:1540(__init__)
#       162    0.000    0.000    0.000    0.000 byteflow.py:1542(<genexpr>)
#         3    0.000    0.000    0.000    0.000 byteflow.py:164(_prune_phis)
#         3    0.000    0.000    0.000    0.000 byteflow.py:172(get_used_phis_per_state)
#         3    0.000    0.000    0.000    0.000 byteflow.py:183(find_use_defs)
#         3    0.000    0.000    0.000    0.000 byteflow.py:196(propagate_phi_map)
#         3    0.000    0.000    0.000    0.000 byteflow.py:218(apply_changes)
#       111    0.000    0.000    0.000    0.000 byteflow.py:241(_is_implicit_new_block)
#         3    0.000    0.000    0.000    0.000 byteflow.py:251(_guard_with_as)
#         3    0.000    0.000    0.000    0.000 byteflow.py:268(__init__)
#       135    0.000    0.000    0.002    0.000 byteflow.py:276(dispatch)
#         3    0.000    0.000    0.000    0.000 byteflow.py:287(op_NOP)
#         8    0.000    0.000    0.000    0.000 byteflow.py:327(op_LOAD_GLOBAL)
#         5    0.000    0.000    0.000    0.000 byteflow.py:332(op_LOAD_DEREF)
#        21    0.000    0.000    0.000    0.000 byteflow.py:337(op_LOAD_CONST)
#         3    0.000    0.000    0.000    0.000 byteflow.py:342(op_LOAD_ATTR)
#        27    0.000    0.000    0.000    0.000 byteflow.py:348(op_LOAD_FAST)
#       115    0.000    0.000    0.000    0.000 byteflow.py:36(__init__)
#        14    0.000    0.000    0.000    0.000 byteflow.py:370(op_STORE_FAST)
#        20    0.000    0.000    0.000    0.000 byteflow.py:60(__init__)
#        12    0.000    0.000    0.001    0.000 byteflow.py:605(_op_POP_JUMP_IF)
#         2    0.000    0.000    0.000    0.000 byteflow.py:633(op_JUMP_ABSOLUTE)
#         7    0.000    0.000    0.000    0.000 byteflow.py:644(op_RETURN_VALUE)
#         2    0.000    0.000    0.000    0.000 byteflow.py:654(op_RAISE_VARARGS)
#         3    0.000    0.000    0.000    0.000 byteflow.py:73(__init__)
#         3    0.000    0.000    0.004    0.001 byteflow.py:78(run)
#         9    0.000    0.000    0.000    0.000 byteflow.py:810(op_CALL_FUNCTION)
#         9    0.000    0.000    0.000    0.000 byteflow.py:812(<listcomp>)
#         1    0.000    0.000    0.000    0.000 bytes.py:1(<module>)
#         2    0.000    0.000    0.000    0.000 caching.py:95(load_overload)
#         2    0.000    0.000    0.000    0.000 caching.py:98(save_overload)
#         3    0.000    0.000    0.000    0.000 callconv.py:105(init_call_helper)
#         3    0.000    0.000    0.002    0.001 callconv.py:116(raise_error)
#         3    0.000    0.000    0.000    0.000 callconv.py:146(decode_arguments)
#        27    0.000    0.000    0.000    0.000 callconv.py:155(_get_arg_packer)
#         3    0.000    0.000    0.000    0.000 callconv.py:343(_make_call_helper)
#         5    0.000    0.000    0.000    0.000 callconv.py:346(return_value)
#         4    0.000    0.000    0.001    0.000 callconv.py:353(set_static_user_exc)
#         4    0.000    0.000    0.002    0.000 callconv.py:385(return_user_exc)
#         8    0.000    0.000    0.000    0.000 callconv.py:399(_get_try_state)
#         8    0.000    0.000    0.000    0.000 callconv.py:409(check_try_status)
#         4    0.000    0.000    0.001    0.000 callconv.py:440(return_status_propagate)
#        13    0.000    0.000    0.000    0.000 callconv.py:447(_return_errcode_raw)
#         7    0.000    0.000    0.001    0.000 callconv.py:454(_get_return_status)
#        10    0.000    0.000    0.000    0.000 callconv.py:478(get_function_type)
#         7    0.000    0.000    0.000    0.000 callconv.py:490(decorate_function)
#         7    0.000    0.000    0.000    0.000 callconv.py:496(<listcomp>)
#         7    0.000    0.000    0.000    0.000 callconv.py:515(type_may_always_need_nrt)
#        10    0.000    0.000    0.000    0.000 callconv.py:535(get_arguments)
#        19    0.000    0.000    0.000    0.000 callconv.py:541(_get_return_argument)
#        23    0.000    0.000    0.000    0.000 callconv.py:544(_get_excinfo_argument)
#         7    0.000    0.000    0.002    0.000 callconv.py:547(call_function)
#         3    0.000    0.000    0.000    0.000 callconv.py:591(__init__)
#         2    0.000    0.000    0.001    0.000 callconv.py:594(fp_zero_division)
#         3    0.000    0.000    0.000    0.000 callconv.py:631(create_error_model)
#        10    0.000    0.000    0.000    0.000 callconv.py:98(get_return_type)
#         1    0.000    0.000    0.005    0.005 callwrapper.py:102(build)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:12(__init__)
#         1    0.000    0.000    0.005    0.005 callwrapper.py:127(build_wrapper)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:130(<listcomp>)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:195(get_env)
#         1    0.000    0.000    0.002    0.002 callwrapper.py:21(add_arg)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:210(_simplified_return_type)
#         2    0.000    0.000    0.000    0.000 callwrapper.py:222(debug_print)
#         2    0.000    0.000    0.000    0.000 callwrapper.py:39(cleanup_arg)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:67(emit_cleanup)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:93(__init__)
#         1    0.000    0.000    0.000    0.000 ccallback.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 ccallback.py:16(_CFuncCompiler)
#         1    0.000    0.000    0.000    0.000 ccallback.py:32(CFunc)
#         1    0.000    0.000    0.000    0.000 cffi_utils.py:184(FFI_from_buffer)
#         1    0.000    0.000    0.001    0.001 cffi_utils.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 cffi_utils.py:204(FFIAttribute)
#         1    0.000    0.000    0.000    0.000 cffiimpl.py:1(<module>)
#        18    0.000    0.000    0.000    0.000 cgutils.py:1147(normalize_ir_text)
#         7    0.000    0.000    0.001    0.000 cgutils.py:124(_make_refs)
#        20    0.000    0.000    0.001    0.000 cgutils.py:142(_get_ptr_by_index)
#        11    0.000    0.000    0.000    0.000 cgutils.py:149(__getattr__)
#        51    0.000    0.000    0.000    0.000 cgutils.py:158(__setattr__)
#        11    0.000    0.000    0.000    0.000 cgutils.py:166(__getitem__)
#         9    0.000    0.000    0.000    0.000 cgutils.py:173(__setitem__)
#         3    0.000    0.000    0.000    0.000 cgutils.py:208(_getvalue)
#         7    0.000    0.000    0.000    0.000 cgutils.py:228(_get_be_type)
#        11    0.000    0.000    0.000    0.000 cgutils.py:231(_cast_member_to_value)
#         9    0.000    0.000    0.000    0.000 cgutils.py:234(_cast_member_from_value)
#         1    0.000    0.000    0.000    0.000 cgutils.py:261(__init__)
#         7    0.000    0.000    0.000    0.000 cgutils.py:308(__setattr__)
#        44    0.000    0.000    0.003    0.000 cgutils.py:362(alloca_once)
#        43    0.000    0.000    0.002    0.000 cgutils.py:417(get_or_insert_function)
#        27    0.000    0.000    0.000    0.000 cgutils.py:435(add_global_variable)
#        15    0.000    0.000    0.000    0.000 cgutils.py:44(make_bytearray)
#        17    0.000    0.000    0.000    0.000 cgutils.py:446(get_null_value)
#         1    0.000    0.000    0.000    0.000 cgutils.py:450(is_null)
#         5    0.000    0.000    0.000    0.000 cgutils.py:455(is_not_null)
#        10    0.000    0.000    0.000    0.000 cgutils.py:460(if_unlikely)
#         4    0.000    0.000    0.000    0.000 cgutils.py:464(if_likely)
#         9    0.000    0.000    0.000    0.000 cgutils.py:56(create_struct_proxy)
#         2    0.000    0.000    0.000    0.000 cgutils.py:794(_scalar_pred_against_zero)
#         2    0.000    0.000    0.000    0.000 cgutils.py:805(is_scalar_zero)
#         4    0.000    0.000    0.000    0.000 cgutils.py:864(if_zero)
#         8    0.000    0.000    0.000    0.000 cgutils.py:876(is_pointer)
#        26    0.000    0.000    0.001    0.000 cgutils.py:893(gep_inbounds)
#        26    0.000    0.000    0.001    0.000 cgutils.py:900(gep)
#         1    0.000    0.000    0.000    0.000 cgutils.py:919(pointer_add)
#        19    0.000    0.000    0.000    0.000 cgutils.py:957(global_constant)
#         7    0.000    0.000    0.001    0.000 cgutils.py:99(__init__)
#         1    0.000    0.000    0.036    0.036 charseq.py:1(<module>)
#         4    0.000    0.000    0.000    0.000 cloudpickle.py:132(_whichmodule)
#         4    0.000    0.000    0.000    0.000 cloudpickle.py:175(_is_importable)
#         4    0.000    0.000    0.000    0.000 cloudpickle.py:195(_lookup_module_and_qualname)
#         4    0.000    0.000    0.000    0.000 cloudpickle_fast.py:390(_class_reduce)
#         4    0.000    0.000    0.000    0.000 cloudpickle_fast.py:566(dump)
#         4    0.000    0.000    0.000    0.000 cloudpickle_fast.py:600(__init__)
#         4    0.000    0.000    0.000    0.000 cloudpickle_fast.py:612(reducer_override)
#         1    0.000    0.000    0.001    0.001 cmathdecl.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:13(CMath_unary)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:29(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:32(CMath_predicate)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:35(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:39(CMath_isfinite)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:44(Cmath_log)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:47(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:49(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:52(Cmath_phase)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:54(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:58(Cmath_polar)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:68(Cmath_rect)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:70(<listcomp>)
#         1    0.000    0.000    0.001    0.001 cmathimpl.py:1(<module>)
#         4    0.000    0.000    0.000    0.000 cmathimpl.py:93(intrinsic_complex_unary)
#         1    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#         7    0.000    0.000    0.000    0.000 codecs.py:319(decode)
#         3    0.000    0.000    0.001    0.000 codegen.py:1014(scan_unresolved_symbols)
#         3    0.000    0.000    0.001    0.000 codegen.py:1033(scan_defined_symbols)
#         3    0.000    0.000    0.000    0.000 codegen.py:1041(resolve)
#         3    0.000    0.000    0.000    0.000 codegen.py:1046(<listcomp>)
#         8    0.000    0.000    0.035    0.004 codegen.py:1059(wrapper)
#         4    0.000    0.000    0.000    0.000 codegen.py:1083(is_symbol_defined)
#         3    0.000    0.000    0.003    0.001 codegen.py:1088(_load_defined_symbols)
#         6    0.000    0.000    0.003    0.000 codegen.py:1092(<setcomp>)
# ...
#         3    0.000    0.000    0.000    0.000 weakref.py:348(__new__)
#         3    0.000    0.000    0.000    0.000 weakref.py:353(__init__)
#       637    0.001    0.000    0.002    0.000 weakref.py:415(__getitem__)
#        31    0.000    0.000    0.000    0.000 weakref.py:428(__setitem__)
#         3    0.000    0.000    0.000    0.000 weakref.py:496(popitem)
#        44    0.000    0.000    0.000    0.000 weakref.py:569(__init__)
#       808    0.003    0.000    0.003    0.000 win32.py:92(_winapi_test)
#       404    0.001    0.000    0.005    0.000 win32.py:98(winapi_test)
#      1212    0.000    0.000    0.003    0.000 win32.py:99(<genexpr>)
#      2058    0.013    0.000    0.013    0.000 {built-in method __new__ of type object at 0x00007FFBFA753C60}
#      1138    0.003    0.000    0.003    0.000 {built-in method _abc._abc_init}
#      7491    0.002    0.000    0.005    0.000 {built-in method _abc._abc_instancecheck}
# 5217/3146    0.005    0.000    0.005    0.000 {built-in method _abc._abc_subclasscheck}
#       140    0.000    0.000    0.000    0.000 {built-in method _abc.get_cache_token}
#         7    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#         3    0.000    0.000    0.000    0.000 {built-in method _ctypes.addressof}
#       872    0.000    0.000    0.000    0.000 {built-in method _ctypes.byref}
#        14    0.000    0.000    0.000    0.000 {built-in method _ctypes.sizeof}
#       442    0.000    0.000    0.000    0.000 {built-in method _functools.reduce}
#         4    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_sha1}
#       100    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#       880    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.create_builtin}
#        18    0.070    0.004    0.070    0.004 {built-in method _imp.create_dynamic}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.exec_builtin}
#     18/15    0.003    0.000    0.010    0.001 {built-in method _imp.exec_dynamic}
#         2    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#       123    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#       880    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.not_}
#         4    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#        48    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_iscased}
#        39    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_tolower}
#         7    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#         7    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#       468    0.001    0.000    0.001    0.000 {built-in method _thread.allocate_lock}
#       532    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#       514    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         7    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#         3    0.000    0.000    0.000    0.000 {built-in method binascii.b2a_base64}
#       462    0.003    0.000    0.008    0.000 {built-in method builtins.__build_class__}
#     56/32    0.000    0.000    0.246    0.008 {built-in method builtins.__import__}
#       476    0.000    0.000    0.000    0.000 {built-in method builtins.all}
# 1398/1391    0.001    0.000    0.005    0.000 {built-in method builtins.any}
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.bin}
#      1026    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.dir}
#        13    0.001    0.000    0.001    0.000 {built-in method builtins.eval}
#     102/1    0.000    0.000    0.777    0.777 {built-in method builtins.exec}
# 14734/14695    0.004    0.000    0.007    0.000 {built-in method builtins.getattr}
# 11627/11435    0.002    0.000    0.024    0.000 {built-in method builtins.hasattr}
# 4035/3757    0.001    0.000    0.001    0.000 {built-in method builtins.hash}
#      2104    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#    119419    0.013    0.000    0.020    0.000 {built-in method builtins.isinstance}
#      4087    0.001    0.000    0.005    0.000 {built-in method builtins.issubclass}
#     12901    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
# 26775/26372    0.003    0.000    0.003    0.000 {built-in method builtins.len}
#       296    0.000    0.000    0.001    0.000 {built-in method builtins.max}
#       201    0.000    0.000    0.000    0.000 {built-in method builtins.min}
# 16585/16391    0.004    0.000    0.022    0.000 {built-in method builtins.next}
#        92    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#       166    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#       285    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#      1098    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
# 1250/1134    0.001    0.000    0.002    0.000 {built-in method builtins.sorted}
#       300    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#       100    0.043    0.000    0.043    0.000 {built-in method io.open_code}
#        15    0.006    0.000    0.006    0.000 {built-in method io.open}
#       100    0.012    0.000    0.012    0.000 {built-in method marshal.loads}
#        14    0.000    0.000    0.000    0.000 {built-in method nt._getfullpathname}
#        22    0.000    0.000    0.000    0.000 {built-in method nt._path_splitroot}
#      1239    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         1    0.000    0.000    0.000    0.000 {built-in method nt.getcwd}
#         4    0.000    0.000    0.000    0.000 {built-in method nt.listdir}
#       470    0.027    0.000    0.027    0.000 {built-in method nt.stat}
#         2    0.000    0.000    0.000    0.000 {built-in method numba._dynfunc.make_function}
#       931    0.000    0.000    0.000    0.000 {built-in method numba.core.typeconv._typeconv.check_compatible}
#        44    0.000    0.000    0.000    0.000 {built-in method numba.core.typeconv._typeconv.get_pointer}
#         7    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#       986    0.001    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.promote_types}
#        15    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         6    0.000    0.000    0.000    0.000 {built-in method sys.audit}
#        10    0.000    0.000    0.000    0.000 {built-in method sys.exc_info}
#       152    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#        89    0.000    0.000    0.000    0.000 {built-in method sys.intern}
#      3154    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         3    0.000    0.000    0.000    0.000 {built-in method zlib.compressobj}
#         4    0.000    0.000    0.000    0.000 {function CloudPickler.dump at 0x00000273216F4430}
#      1546    0.000    0.000    0.000    0.000 {function _typedict.__getitem__ at 0x000002731FE1F670}
#        89    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#       122    0.004    0.000    0.004    0.000 {method '__exit__' of '_io._IOBase' objects}
#       680    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#       532    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__init_subclass__' of 'object' objects}
#        42    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#         2    0.000    0.000    0.000    0.000 {method '_insert' of '_dispatcher.Dispatcher' objects}
#         3    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#      1179    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#      6602    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#        34    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#     15707    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 {method 'center' of 'str' objects}
#      1191    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#       212    0.000    0.000    0.000    0.000 {method 'clear' of 'frame' objects}
#        27    0.000    0.000    0.000    0.000 {method 'clear' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'compress' of 'zlib.Compress' objects}
#      1217    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        74    0.000    0.000    0.000    0.000 {method 'copy' of 'set' objects}
#       202    0.000    0.000    0.000    0.000 {method 'decode' of 'bytearray' objects}
#       208    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#        41    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       146    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#       745    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#      2371    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'expandtabs' of 'str' objects}
#        27    0.000    0.000    0.000    0.000 {method 'extend' of 'collections.deque' objects}
#     14800    0.001    0.000    0.001    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'findall' of 're.Pattern' objects}
#         3    0.000    0.000    0.000    0.000 {method 'flush' of 'zlib.Compress' objects}
# 5417/3224    0.003    0.000    0.011    0.000 {method 'format' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'from_address' of '_ctypes.PyCArrayType' objects}
#     11998    0.002    0.000    0.005    0.000 {method 'get' of 'dict' objects}
#        82    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         4    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#        14    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#       242    0.000    0.000    0.000    0.000 {method 'group' of 're.Match' objects}
#        76    0.000    0.000    0.000    0.000 {method 'groupdict' of 're.Match' objects}
#         1    0.000    0.000    0.000    0.000 {method 'groups' of 're.Match' objects}
#         1    0.000    0.000    0.000    0.000 {method 'in_dll' of '_ctypes.UnionType' objects}
#        14    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#       527    0.000    0.000    0.000    0.000 {method 'index' of 'tuple' objects}
#      1011    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#       101    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#        32    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#       438    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#      1612    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        75    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {method 'join' of 'bytes' objects}
# 2842/2831    0.001    0.000    0.003    0.000 {method 'join' of 'str' objects}
#       492    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#       262    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#       145    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#       278    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         7    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#         2    0.000    0.000    0.000    0.000 {method 'newbyteorder' of 'numpy.generic' objects}
#        97    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#        26    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.deque' objects}
#      2466    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#      1982    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        14    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 {method 'popitem' of 'dict' objects}
#        97    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#       114    0.027    0.000    0.027    0.000 {method 'read' of '_io.BufferedReader' objects}
#         1    0.002    0.002    0.002    0.002 {method 'readline' of '_io.BufferedReader' objects}
#         1    0.001    0.001    0.001    0.001 {method 'readlines' of '_io._IOBase' objects}
#      1179    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#       196    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        10    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#       795    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#       400    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#      1020    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#        57    0.000    0.000    0.000    0.000 {method 'rsplit' of 'str' objects}
#      2759    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#        11    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#        11    0.000    0.000    0.000    0.000 {method 'setter' of 'property' objects}
#        75    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#       338    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#       192    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#      7422    0.002    0.000    0.002    0.000 {method 'startswith' of 'str' objects}
#       371    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        61    0.001    0.000    0.001    0.000 {method 'sub' of 're.Pattern' objects}
#         2    0.000    0.000    0.000    0.000 {method 'tobytes' of 'numpy.generic' objects}
#      1359    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       174    0.000    0.000    0.000    0.000 {method 'update' of 'set' objects}
#       635    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        46    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#      5398    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}
#       103    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#       106    0.000    0.000    0.000    0.000 {method 'with_traceback' of 'BaseException' objects}
#       596    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %% [markdown]
# When we run the two pieces of code, we notice two things. Firstly, the version with the Numba decortator compiles much faster (when I ran it, about 0.3s compared to about 6s). The second is that the list of called functions is much longer in the compiled version. This is because cProfile has recorded the process of compilation as well as the running of the code. Most of this complexity is simply the detail of the implementation and can be ignored.
#
# The important thing to notice is that Numba was able to speed up the execution of this code significantly with minimal changes to the source code required. This makes Numba a good choice to easily get some extra speed, by compiling heavily used functions in your code.
